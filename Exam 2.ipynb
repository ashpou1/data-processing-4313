# %% [markdown]
# <a href="https://colab.research.google.com/github/ashpou1/data-processing-4313/blob/main/Exam%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ASHOK SHARMA POUDEL
# #218380
# #DATA PROCESSING VISUALIZATION  4313
# #DR. NICHOLAS JACOB
#
# ---
#
#
# ## EXAM 2

# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Viz/main/Activity_Dataset_V1.csv')

df.head(20)
# Out:
#     Unnamed: 0 activity_day     workout_type  distance  time  calories  \
# 0            0   2022-01-01        Freestyle      9.30    77       123
# 1            1   2022-01-01        Freestyle      3.44    96        55
# 2            2   2022-01-01   Indoor Cycling      6.34    85        33
# 3            3   2022-01-01          Walking      7.91    42        82
# 4            4   2022-01-01       Open Water      8.99    36       131
# 5            5   2022-01-01  Outdoor Cycling      5.47   117       144
# 6            6   2022-01-01   Indoor Cycling      6.28    66       378
# 7            7   2022-01-01  Outdoor Running      2.94    26       430
# 8            8   2022-01-01        Trail Run      2.87    26       465
# 9            9   2022-01-01    Pool Swimming      3.91    23        99
# 10          10   2022-01-01        Trail Run      6.31   107        97
# 11          11   2022-01-01  Outdoor Running      2.37    65       524
# ...

# %% [markdown]
# ltes check out data types

# %%
df.dtypes
# Out:
# Unnamed: 0          int64
# activity_day       object
# workout_type       object
# distance          float64
# time                int64
# calories            int64
# total_steps       float64
# avg_speed         float64
# avg_cadence       float64
# max_cadence       float64
# avg_pace           object
# max_pace           object
# min_pace           object
# avg_heart_rate    float64
# max_heart_rate    float64
# min_heart_rate      int64
# vo2_max(%)          int64
# aerobic(%)          int64
# anaerobic(%)        int64
# intensive(%)        int64
# light(%)            int64
# dtype: object

# %% [markdown]
# (b) (10 points) Remove the column that repeats the indexes and is ‘unnamed’ as a column.

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.head()
#https://stackoverflow.com/questions/43983622/remove-unnamed-columns-in-pandas-dataframe
# Out:
#   activity_day    workout_type  distance  time  calories  total_steps  \
# 0   2022-01-01       Freestyle      9.30    77       123          NaN
# 1   2022-01-01       Freestyle      3.44    96        55          NaN
# 2   2022-01-01  Indoor Cycling      6.34    85        33          NaN
# 3   2022-01-01         Walking      7.91    42        82       1571.0
# 4   2022-01-01      Open Water      8.99    36       131          NaN
#
#    avg_speed  avg_cadence  max_cadence avg_pace max_pace min_pace  \
# 0      18.88       168.54       138.30      NaN      NaN      NaN
# 1      29.65       125.92       292.81      NaN      NaN      NaN
# 2      17.85        81.93       323.69      NaN      NaN      NaN
# 3      22.10        29.63       180.16    07:58    28:58    07:58
# 4      25.83        64.55       342.89      NaN      NaN      NaN
#
#    avg_heart_rate  max_heart_rate  min_heart_rate  vo2_max(%)  aerobic(%)  \
# ...

# %% [markdown]
# (c) (10 points) Clean the column names to remove the unit declaration, (%), using regular expressions. The column name should not have any trailing spaces after cleaning. You will only receive partial credit for simply renaming
# columns without using regular expressions.

# %%
df.columns
# Out:
# Index(['activity_day', 'workout_type', 'distance', 'time', 'calories',
#        'total_steps', 'avg_speed', 'avg_cadence', 'max_cadence', 'avg_pace',
#        'max_pace', 'min_pace', 'avg_heart_rate', 'max_heart_rate',
#        'min_heart_rate', 'vo2_max(%)', 'aerobic(%)', 'anaerobic(%)',
#        'intensive(%)', 'light(%)'],
#       dtype='object')

# %%
col = df.columns.map(lambda s: re.sub(r"\((.+)\)","",s))
df.head()
# Out:
#   activity_day    workout_type  distance  time  calories  total_steps  \
# 0   2022-01-01       Freestyle      9.30    77       123          NaN
# 1   2022-01-01       Freestyle      3.44    96        55          NaN
# 2   2022-01-01  Indoor Cycling      6.34    85        33          NaN
# 3   2022-01-01         Walking      7.91    42        82       1571.0
# 4   2022-01-01      Open Water      8.99    36       131          NaN
#
#    avg_speed  avg_cadence  max_cadence avg_pace max_pace min_pace  \
# 0      18.88       168.54       138.30      NaN      NaN      NaN
# 1      29.65       125.92       292.81      NaN      NaN      NaN
# 2      17.85        81.93       323.69      NaN      NaN      NaN
# 3      22.10        29.63       180.16    07:58    28:58    07:58
# 4      25.83        64.55       342.89      NaN      NaN      NaN
#
#    avg_heart_rate  max_heart_rate  min_heart_rate  vo2_max(%)  aerobic(%)  \
# ...

# %% [markdown]
# https://github.com/ashpou1/data-processing-4313/blob/main/cleaning%20strings%2015.ipynb

# %% [markdown]
# (d) (10 points) Convert ‘activity day’ column into a datetime format.

# %%
df.activity_day = pd.to_datetime(df['activity_day'])
df.dtypes
# Out:
# activity_day      datetime64[ns]
# workout_type              object
# distance                 float64
# time                       int64
# calories                   int64
# total_steps              float64
# avg_speed                float64
# avg_cadence              float64
# max_cadence              float64
# avg_pace                  object
# max_pace                  object
# min_pace                  object
# avg_heart_rate           float64
# max_heart_rate           float64
# min_heart_rate             int64
# vo2_max(%)                 int64
# aerobic(%)                 int64
# anaerobic(%)               int64
# intensive(%)               int64
# light(%)                   int64
# dtype: object

# %% [markdown]
# https://github.com/nurfnick/Data_Viz/blob/main/mySolutions.ipynb

# %% [markdown]
# (e) (10 points) Impute ‘total steps’ by replacing the ‘NaN’s with an appropriate number of steps. Convert to appropriate
# datatype.

# %%
df.isnull().sum(axis = 0)
# Out:
# activity_day        0
# workout_type        0
# distance            0
# time                0
# calories            0
# total_steps       446
# avg_speed           0
# avg_cadence         0
# max_cadence         0
# avg_pace          446
# max_pace          446
# min_pace          446
# avg_heart_rate      0
# max_heart_rate      0
# min_heart_rate      0
# vo2_max(%)          0
# aerobic(%)          0
# anaerobic(%)        0
# intensive(%)        0
# light(%)            0
# dtype: int64

# %%
df.total_steps = df.total_steps.fillna(value = 0)
df.avg_pace = df.avg_pace.fillna(value = 0)
df.max_pace = df.max_pace.fillna(value = 0)
df.min_pace = df.min_pace.fillna(value = 0)
df
# Out:
#     activity_day    workout_type  distance  time  calories  total_steps  \
# 0     2022-01-01       Freestyle      9.30    77       123          0.0
# 1     2022-01-01       Freestyle      3.44    96        55          0.0
# 2     2022-01-01  Indoor Cycling      6.34    85        33          0.0
# 3     2022-01-01         Walking      7.91    42        82       1571.0
# 4     2022-01-01      Open Water      8.99    36       131          0.0
# ..           ...             ...       ...   ...       ...          ...
# 995   2022-02-14   Pool Swimming      6.92   101       313          0.0
# 996   2022-02-14       Freestyle      9.48    61       219          0.0
# 997   2022-02-14       Freestyle      3.30    40       169          0.0
# 998   2022-02-14  Indoor Cycling      4.40    47        52          0.0
# 999   2022-02-14  Indoor Cycling      1.57   116       106          0.0
#
#      avg_speed  avg_cadence  max_cadence avg_pace max_pace min_pace  \
# ...

# %% [markdown]
# https://github.com/ashpou1/data-processing-4313/blob/main/imputing%2019.ipynb

# %% [markdown]
# (f) (10 points) Convert non-empty ‘avg pace’ into a float that is still representative of the information contained in the
# column. Recall that there are 60 seconds in one minute so 3:30 is equivalent to 3.5 minutes.

# %%
df.dtypes
# Out:
# activity_day      datetime64[ns]
# workout_type              object
# distance                 float64
# time                       int64
# calories                   int64
# total_steps              float64
# avg_speed                float64
# avg_cadence              float64
# max_cadence              float64
# avg_pace                  object
# max_pace                  object
# min_pace                  object
# avg_heart_rate           float64
# max_heart_rate           float64
# min_heart_rate             int64
# vo2_max(%)                 int64
# aerobic(%)                 int64
# anaerobic(%)               int64
# intensive(%)               int64
# light(%)                   int64
# dtype: object

# %%
df.avg_pace = pd.to_datetime(df['avg_pace'])

# %% [markdown]
# (g) (10 points) Group data by ‘workout type’ and find the mean, median, count and standard deviation of ‘calories’.

# %%
df.groupby('workout_type').calories.agg(['mean','median','count','std'])
# Out:
#                        mean  median  count         std
# workout_type
# Cricket          307.548387   330.0     93  149.950609
# Freestyle        278.552083   294.0     96  163.703768
# Indoor Cycling   280.450000   306.0     80  156.633322
# Open Water       296.747253   328.0     91  160.068499
# Outdoor Cycling  299.129412   301.0     85  158.731263
# Outdoor Running  301.469136   349.0     81  165.725080
# Pool Swimming    283.414894   300.0     94  157.576703
# Trail Run        267.966667   264.0     90  155.748533
# Treadmill        278.142857   269.5     98  146.963352
# Trekking         283.127660   280.5     94  151.034870
# Walking          276.040816   270.5     98  157.287570

# %% [markdown]
# https://github.com/nurfnick/Data_Viz/blob/main/20_Cleaning_Conclusion.ipynb

# %% [markdown]
# (h) (10 points) Create an indicator column that identifies if the activity achieved 30% or more ‘aerobic’ activity.

# %%
bal = df['aerobic(%)'] >= (30)
pd.concat([df,pd.DataFrame({'thirty_plus':bal})], axis = 1)
# Out:
#     activity_day    workout_type  distance  time  calories  total_steps  \
# 0     2022-01-01       Freestyle      9.30    77       123          0.0
# 1     2022-01-01       Freestyle      3.44    96        55          0.0
# 2     2022-01-01  Indoor Cycling      6.34    85        33          0.0
# 3     2022-01-01         Walking      7.91    42        82       1571.0
# 4     2022-01-01      Open Water      8.99    36       131          0.0
# ..           ...             ...       ...   ...       ...          ...
# 995   2022-02-14   Pool Swimming      6.92   101       313          0.0
# 996   2022-02-14       Freestyle      9.48    61       219          0.0
# 997   2022-02-14       Freestyle      3.30    40       169          0.0
# 998   2022-02-14  Indoor Cycling      4.40    47        52          0.0
# 999   2022-02-14  Indoor Cycling      1.57   116       106          0.0
#
#      avg_speed  avg_cadence  max_cadence            avg_pace  ... min_pace  \
# ...

# %% [markdown]
# https://github.com/nurfnick/Data_Viz/blob/main/20_Cleaning_Conclusion.ipynb

# %% [markdown]
# (i) (10 points) Which day of the week (Monday, Tuesday, etc.) and ‘workout type‘ has the maximum of the ‘max cadence’

# %%
df.groupby([df.activity_day.dt.day_name(),df.max_cadence,df.workout_type]).agg('count')
# Out:
#                                           activity_day  distance  time  \
# activity_day max_cadence workout_type
# Friday       52.70       Outdoor Cycling             1         1     1
#              54.50       Trekking                    1         1     1
#              54.60       Freestyle                   1         1     1
#              55.41       Indoor Cycling              1         1     1
#              55.75       Freestyle                   1         1     1
# ...                                                ...       ...   ...
# Wednesday    337.74      Walking                     1         1     1
#              339.65      Trekking                    1         1     1
#              345.65      Pool Swimming               1         1     1
#              349.66      Treadmill                   1         1     1
#              349.78      Pool Swimming               1         1     1
#
# ...

# %% [markdown]
# https://github.com/nurfnick/Data_Viz/blob/main/20_Cleaning_Conclusion.ipynb

# %% [markdown]
# (a)
# it took me almost 5 hours. longer than exam one because i miss 2 of the classes.
#
#
# (b)
# hardest one was the one hot encoder and easiest are strings
#
#
# (c)
# i will say dates. i always have hard time with dates
