# %% [markdown]
# <a href="https://colab.research.google.com/github/ashpou1/data-processing-4313/blob/main/Recreating%20Masters%20Proposal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ASHOK SHARMA POUDEL
# #218380
# #DATA PROCESSING VISUALIZATION  4313
# #DR. NICHOLAS JACOB

# %% [markdown]
# #Recreate Masters Proposal

# %% [markdown]
# I am using the data set from kaggle about waste management in Singapore. This data set contains diffent years and shows what kind of waste. It also includes data of recycled waste and unrecycle waste. This will give us the oppurtunity to how the waist management working and how effective to do waste managenet.

# %% [markdown]
# [Singapore waste management ](https://www.kaggle.com/datasets/kingabzpro/singapore-waste-management)

# %%
#instal kaggle
# !pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-9e30f361-698b-40a4-bd7d-1af32ec03d9f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9e30f361-698b-40a4-bd7d-1af32ec03d9f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"aspoudel","key":"d87abb0eb00e1daaf986ff8d6cf3bb73"}'}

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle detaset list
# Out:
# usage: kaggle [-h] [-v] {competitions,c,datasets,d,kernels,k,config} ...
# kaggle: error: argument command: invalid choice: 'detaset' (choose from 'competitions', 'c', 'datasets', 'd', 'kernels', 'k', 'config')

# %%
# !unzip singapore-waste-management.zip
# Out:
# unzip:  cannot find or open singapore-waste-management.zip, singapore-waste-management.zip.zip or singapore-waste-management.zip.ZIP.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as #for some extra annimation
import plotly.graph_objects as go
import warnings
warnings.filterwarnings('ignore')

# %%
! kaggle datasets download -d kingabzpro/singapore-waste-management
# Out:
# ...
#   0% 0.00/4.34k [00:00<?, ?B/s]
# 100% 4.34k/4.34k [00:00<00:00, 3.16MB/s]

# %%
! unzip singapore-waste-management.zip
# Out:
# Archive:  singapore-waste-management.zip
#   inflating: 2003_2017_waste.csv
#   inflating: 2018_2020_waste.csv
#   inflating: waste_energy_stat.csv

# %% [markdown]
# ![viz1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# This is one of visualization that show the kind of the waste and their amount containe in total amount of waste. It reflects each and how much waste we need to control to be enviromentalist. Its shows life style and their reflection of their effort to manage the waste and recycles.

# %% [markdown]
# i will be working with three data set so it will make it harder. As i will wokr one it there will be alot of data set to remember.
