# %% [markdown]
# <a href="https://colab.research.google.com/github/ashpou1/data-processing-4313/blob/main/unfinish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ASHOK SHARMA POUDEL
# #218380
# #DATA PROCESSING VISUALIZATION  4313
# #DR. NICHOLAS JACOB

# %% [markdown]
# Quiz 1
# jupiter notebook and python

# %% [markdown]
# ##Iris-setosa, Iris-versicolor, Iris-virginica![iris.png](data:image/png;base64,...)

# %%
import numpy as np #a matrix like package for handling data
import pandas as pd #a R like package for handling data
from scipy import stats #a way to just get a piece of a large package
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Viz/main/iris.csv')

df
# Out:
#      SepalLength  SepalWidth  PedalLength  PedalWidth           Class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #lets make a bar chart for different kind of these lovely purple flowers.

# %%
dfg.plot(kind='bar', title='kinds of flower', ylabel='number of flowers',
         xlabel='flower', figsize=(10, 5))

# %% [markdown]
# Lets do pie too and see

# %%
dfg.plot(kind= 'pie')

# %% [markdown]
# #lets do some more visualization

# %% [markdown]
# #Histogram

# %%
head = ['SepalLength','SepalWidth','PedalLength','PedalWidth','Class']
df.columns = head
df.head()
# Out:
#    SepalLength  SepalWidth  PedalLength  PedalWidth        Class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
df.PedalWidth.plot(kind = 'hist')

# %% [markdown]
# #Mean and SD of Pedal width

# %%
df.PedalWidth.mean()
# Out:
# 1.1986666666666672

# %%
df.PedalWidth.std()
# Out:
# 0.7631607417008414

# %% [markdown]
# #Box plot

# %%
df.SepalWidth.plot(kind = 'box')

# %% [markdown]
# #Mean and SD of sepal width

# %%
df.SepalWidth.mean()
# Out:
# 3.0540000000000007

# %%
df.SepalWidth.std()
# Out:
# 0.4335943113621737

# %% [markdown]
# #Violin

# %%
sns.violinplot(data = df.PedalLength)

# %% [markdown]
# #Mean and SD of Pedal length

# %%
df.PedalLength.mean()
# Out:
# 3.7586666666666693

# %%
df.PedalLength.std()
# Out:
# 1.7644204199522617

# %% [markdown]
# ##Pandas for Data Analysis

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Viz/main/iris.csv', header= None)
head = ['SepalLength','SepalWidth','PedalLength','PedalWidth','Class']
df.columns= head
df.head()
# Out:
#    SepalLength  SepalWidth  PedalLength  PedalWidth        Class
# 0  SepalLength  SepalWidth  PedalLength  PedalWidth        Class
# 1          5.1         3.5          1.4         0.2  Iris-setosa
# 2          4.9         3.0          1.4         0.2  Iris-setosa
# 3          4.7         3.2          1.3         0.2  Iris-setosa
# 4          4.6         3.1          1.5         0.2  Iris-setosa

# %%
df.columns
# Out:
# Index(['SepalLength', 'SepalWidth', 'PedalLength', 'PedalWidth', 'Class'], dtype='object')

# %%
df.describe()
# Out:
#        SepalLength SepalWidth PedalLength PedalWidth           Class
# count          151        151         151        151             151
# unique          36         24          44         23               4
# top            5.0        3.0         1.5        0.2  Iris-virginica
# freq            10         26          14         28              50

# %% [markdown]
# calling sepal length column

# %%
df['PedalLength']
# Out:
# 0      PedalLength
# 1              1.4
# 2              1.4
# 3              1.3
# 4              1.5
#           ...
# 146            5.2
# 147            5.0
# 148            5.2
# 149            5.4
# 150            5.1
# Name: PedalLength, Length: 151, dtype: object

# %%
df.groupby('Pedallength').mean()

# %%
df.query('Class ==1 and pedallenth >5, sepallenght >7')

# %% [markdown]
# Call a column, find it's mean
#
# Find the last row
#
# Melt the data keeping two columns of values and the type of flower
#
# Select flowers that have pedal length greater than 5 and sepal length less than 7
#
# Group the data by type of flower and compute mean and median
