# %% [markdown]
# <a href="https://colab.research.google.com/github/ashpou1/data-processing-4313/blob/main/Recreating%20masters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#instal kaggle
# !pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-5d85f525-36db-4800-8de4-dbf1ad6142de" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5d85f525-36db-4800-8de4-dbf1ad6142de">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"aspoudel","key":"d87abb0eb00e1daaf986ff8d6cf3bb73"}'}

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle detaset list
# Out:
# usage: kaggle [-h] [-v] {competitions,c,datasets,d,kernels,k,config} ...
# kaggle: error: argument command: invalid choice: 'detaset' (choose from 'competitions', 'c', 'datasets', 'd', 'kernels', 'k', 'config')

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import warnings
warnings.filterwarnings('ignore')

# %%
! kaggle datasets download -d kingabzpro/singapore-waste-management
# Out:
# Downloading singapore-waste-management.zip to /content
#   0% 0.00/4.34k [00:00<?, ?B/s]
# 100% 4.34k/4.34k [00:00<00:00, 3.03MB/s]

# %%
! unzip singapore-waste-management.zip
# Out:
# Archive:  singapore-waste-management.zip
#   inflating: 2003_2017_waste.csv
#   inflating: 2018_2020_waste.csv
#   inflating: waste_energy_stat.csv

# %% [markdown]
# ##LOADING DATA AND DATA CLEANING
#
# ---

# %% [markdown]
# ##DATA FROM 2003 TO 2017
#
# ---

# %%
#DATA 1
df= pd.read_csv('2003_2017_waste.csv')
df
# Out:
#                                  waste_type  waste_disposed_of_tonne  \
# 0                                      Food                   679900
# 1                           Paper/Cardboard                   576000
# 2                                  Plastics                   762700
# 3                                       C&D                     9700
# 4                       Horticultural waste                   111500
# ..                                      ...                      ...
# 220                          Ash and sludge                   214800
# 221                                 Plastic                   763400
# 222                         Textile/Leather                   141200
# 223  Others (stones, ceramic, rubber, etc.)                   319300
# 224                                   Total                  2980000
#
#      total_waste_recycled_tonne  total_waste_generated_tonne  recycling_rate  \
# 0                      111100.0                       791000            0.14
# 1                      607100.0                      1183100            0.51
# 2                       59500.0                       822200            0.07
# 3                     1585700.0                      1595400            0.99
# 4                      209000.0                       320500            0.65
# ..                          ...                          ...             ...
# 220                     28600.0                       243400            0.12
# 221                     51800.0                       815200            0.06
# 222                      9600.0                       150800            0.06
# 223                      7100.0                       326400            0.02
# 224                   4724300.0                      7704300            0.61
#
#      year
# 0    2016
# 1    2016
# 2    2016
# 3    2016
# 4    2016
# ..    ...
# 220  2017
# 221  2017
# 222  2017
# 223  2017
# 224  2017
#
# [225 rows x 6 columns]

# %%
df.dtypes
# Out:
# waste_type                      object
# waste_disposed_of_tonne          int64
# total_waste_recycled_tonne     float64
# total_waste_generated_tonne      int64
# recycling_rate                 float64
# year                             int64
# dtype: object

# %%
cols=set(df.columns)-{'year'}
df0 = df[list(cols)]
df0.describe()
#removing year from dataframe and creating describe as "df0"
# Out:
#        total_waste_generated_tonne  total_waste_recycled_tonne  \
# count                 2.250000e+02                2.250000e+02
# mean                  8.594173e+05                4.896987e+05
# std                   1.579112e+06                9.607678e+05
# min                   1.440000e+04                0.000000e+00
# 25%                   1.184000e+05                1.830000e+04
# 50%                   3.324000e+05                9.110000e+04
# 75%                   8.098000e+05                5.200000e+05
# max                   7.851500e+06                4.825900e+06
#
#        waste_disposed_of_tonne  recycling_rate
# count             2.250000e+02      225.000000
# mean              3.697191e+05        0.481778
# std               6.842470e+05        0.365106
# min               1.300000e+03        0.000000
# 25%               2.460000e+04        0.110000
# 50%               1.062000e+05        0.490000
# 75%               5.000000e+05        0.850000
# max               3.045200e+06        0.990000

# %%
df = df.rename(columns = {'waste_disposed_of_tonne': 'waste_disposed', 'total_waste_recycled_tonne': 'waste_recycled',
                                 'total_waste_generated_tonne': 'waste_generated'})
df
#changing the name and throwing tonnes
# Out:
#                                  waste_type  waste_disposed  waste_recycled  \
# 0                                      Food          679900        111100.0
# 1                           Paper/Cardboard          576000        607100.0
# 2                                  Plastics          762700         59500.0
# 3                                       C&D            9700       1585700.0
# 4                       Horticultural waste          111500        209000.0
# ..                                      ...             ...             ...
# 220                          Ash and sludge          214800         28600.0
# 221                                 Plastic          763400         51800.0
# 222                         Textile/Leather          141200          9600.0
# 223  Others (stones, ceramic, rubber, etc.)          319300          7100.0
# 224                                   Total         2980000       4724300.0
#
#      waste_generated  recycling_rate  year
# 0             791000            0.14  2016
# 1            1183100            0.51  2016
# 2             822200            0.07  2016
# 3            1595400            0.99  2016
# 4             320500            0.65  2016
# ..               ...             ...   ...
# 220           243400            0.12  2017
# 221           815200            0.06  2017
# 222           150800            0.06  2017
# 223           326400            0.02  2017
# 224          7704300            0.61  2017
#
# [225 rows x 6 columns]

# %%
df['waste_recycled'] = df['waste_recycled'].apply(lambda x: int(x))
df['waste_recycled'] = df['waste_recycled'].replace(".0","")
df.iloc[:5]
#converting datatypes int  to from float
# Out:
#             waste_type  waste_disposed  waste_recycled  waste_generated  \
# 0                 Food          679900          111100           791000
# 1      Paper/Cardboard          576000          607100          1183100
# 2             Plastics          762700           59500           822200
# 3                  C&D            9700         1585700          1595400
# 4  Horticultural waste          111500          209000           320500
#
#    recycling_rate  year
# 0            0.14  2016
# 1            0.51  2016
# 2            0.07  2016
# 3            0.99  2016
# 4            0.65  2016

# %%
df.isnull().sum()
#checking for any null values
# Out:
# waste_type         0
# waste_disposed     0
# waste_recycled     0
# waste_generated    0
# recycling_rate     0
# year               0
# dtype: int64

# %%
df.dtypes
# Out:
# waste_type          object
# waste_disposed       int64
# waste_recycled       int64
# waste_generated      int64
# recycling_rate     float64
# year                 int64
# dtype: object

# %% [markdown]
# ##DATA FROM 2018 TO 2020
#
# ---

# %%
#DATA 2
df1= pd.read_csv('2018_2020_waste.csv')
df1
# Out:
#                                Waste Type  Total Generated ('000 tonnes)  \
# 0                Construction& Demolition                           1624
# 1                           Ferrous Metal                           1269
# 2                         Paper/Cardboard                           1054
# 3                                Plastics                            949
# 4                                    Food                            763
# 5                                    Wood                            521
# 6                           Horticultural                            320
# 7                            Ash & Sludge                            240
# 8                         Textile/Leather                            220
# 9                               Used Slag                            181
# 10                      Non-Ferrous Metal                            171
# 11                                  Glass                             64
# 12                            Scrap Tyres                             32
# 13  Others (stones, ceramic, rubber, ect)                            286
# 14                                Overall                           7695
# 15               Construction& Demolition                           1440
# 16                          Ferrous Metal                           1278
# 17                        Paper/Cardboard                           1011
# 18                               Plastics                            930
# 19                                   Food                           7440
# 20                                   Wood                            438
# 21                          Horticultural                            400
# 22                           Ash & Sludge                            252
# 23                        Textile/Leather                            168
# 24                              Used Slag                            129
# 25                      Non-Ferrous Metal                            126
# 26                                  Glass                             75
# 27                            Scrap Tyres                             33
# 28  Others (stones, ceramic, rubber, ect)                            210
# 29                                Overall                           7234
# 30                        Paper/Cardboard                           1144
# 31                          Ferrous metal                            934
# 32                               Plastics                            868
# 33              Construction & Demolition                            825
# 34                                   Food                            665
# 35                          Horticultural                            313
# 36                                   Wood                            304
# 37                           Ash & sludge                            228
# 38                        Textile/Leather                            137
# 39                              Used slag                            106
# 40                      Non-ferrous metal                             75
# 41                                  Glass                             66
# 42                            Scrap tyres                             23
# 43        Others (stones, ceramics, etc.)                            193
# 44                                Overall                           5880
#
#     Total Recycled ('000 tonnes)  Year
# 0                           1618  2018
# 1                            126  2018
# 2                            586  2018
# 3                             41  2018
# 4                            126  2018
# 5                            428  2018
# 6                            227  2018
# 7                             25  2018
# 8                             14  2018
# 9                            179  2018
# 10                           170  2018
# 11                            12  2018
# 12                            29  2018
# 13                            11  2018
# 14                          4726  2018
# 15                          1434  2019
# 16                          1270  2019
# 17                           449  2019
# 18                            37  2019
# 19                           136  2019
# 20                           289  2019
# 21                           293  2019
# 22                            25  2019
# 23                             6  2019
# 24                           127  2019
# 25                           124  2019
# 26                            11  2019
# 27                            31  2019
# 28                            15  2019
# 29                          4247  2019
# 30                           432  2020
# 31                           930  2020
# 32                            36  2020
# 33                           822  2020
# 34                           126  2020
# 35                           249  2020
# 36                           195  2020
# 37                            16  2020
# 38                             6  2020
# 39                           104  2020
# 40                            73  2020
# 41                             7  2020
# 42                            22  2020
# 43                            21  2020
# 44                          3040  2020

# %%
df1.dtypes
# Out:
# Waste Type                       object
# Year                              int64
# Total Generated ('000 tonnes)     int64
# Total Recycled ('000 tonnes)      int64
# dtype: object

# %%
cols=set(df1.columns)-{'year'}
df00 = df1[list(cols)]
df00.describe()
#removing year from dataframe and create describe as "df00"
# Out:
#               Year  Total Generated ('000 tonnes)  \
# count    45.000000                      45.000000
# mean   2019.000000                    1073.644444
# std       0.825723                    1951.504154
# min    2018.000000                      23.000000
# 25%    2018.000000                     168.000000
# 50%    2019.000000                     313.000000
# 75%    2020.000000                     949.000000
# max    2020.000000                    7695.000000
#
#        Total Recycled ('000 tonnes)
# count                     45.000000
# mean                     508.688889
# std                     1035.912023
# min                        6.000000
# 25%                       25.000000
# 50%                      126.000000
# 75%                      428.000000
# max                     4726.000000

# %%
df1 = df1.rename(columns={"Waste Type": "waste_type", "Total Generated ('000 tonnes)":"total_generated", "Total Recycled ('000 tonnes)": "total_recycled",'Year':'year'})
df1.head()
#changing names and removing other extra
# Out:
#                  waste_type  total_generated  total_recycled  year
# 0  Construction& Demolition             1624            1618  2018
# 1             Ferrous Metal             1269             126  2018
# 2           Paper/Cardboard             1054             586  2018
# 3                  Plastics              949              41  2018
# 4                      Food              763             126  2018

# %%
df1['waste_disposed'] =df1['total_generated']*1000
df1['waste_recycled'] = df1['total_recycled']*1000
df1['waste_generated'] = (df1['total_generated'] + df1['total_recycled'])*1000
df1['recycling_rate'] = df1['waste_recycled']/df1['waste_generated']
df1.head()
#changing tons to kilograms and creating waste generated and recyling rate.
# Out:
#                  waste_type  total_generated  total_recycled  year  \
# 0  Construction& Demolition             1624            1618  2018
# 1             Ferrous Metal             1269             126  2018
# 2           Paper/Cardboard             1054             586  2018
# 3                  Plastics              949              41  2018
# 4                      Food              763             126  2018
#
#    waste_disposed  waste_recycled  waste_generated  recycling_rate
# 0         1624000         1618000          3242000        0.499075
# 1         1269000          126000          1395000        0.090323
# 2         1054000          586000          1640000        0.357317
# 3          949000           41000           990000        0.041414
# 4          763000          126000           889000        0.141732

# %%
df1= df1.drop(["total_generated","total_recycled"], axis = 1)
df1.head()
#droping total generated and total recycled
# Out:
#                  waste_type  year  waste_disposed  waste_recycled  \
# 0  Construction& Demolition  2018         1624000         1618000
# 1             Ferrous Metal  2018         1269000          126000
# 2           Paper/Cardboard  2018         1054000          586000
# 3                  Plastics  2018          949000           41000
# 4                      Food  2018          763000          126000
#
#    waste_generated  recycling_rate
# 0          3242000        0.499075
# 1          1395000        0.090323
# 2          1640000        0.357317
# 3           990000        0.041414
# 4           889000        0.141732

# %%
df1.isnull().sum()
#finding null values
# Out:
# waste_type         0
# year               0
# waste_disposed     0
# waste_recycled     0
# waste_generated    0
# recycling_rate     0
# dtype: int64

# %% [markdown]
# ##lets work on our final data

# %% [markdown]
# ##DATA OF ENERGY FROM WASTE
#
# ---

# %%
#DATA 3
df2= pd.read_csv('waste_energy_stat.csv')
df2
# Out:
#   The table gives the amount of energy saved in kilowatt hour (kWh) and the amount of crude oil (barrels) by recycling 1 metric tonne (1000 kilogram)  per waste type  \
# 0    1 barrel oil is approximately 159 litres of oil
# 1                                                NaN
# 2                                           material
# 3                                       energy_saved
# 4                                    crude_oil saved
#
#    Unnamed: 1    Unnamed: 2     Unnamed: 3         Unnamed: 4  Unnamed: 5
# 0         NaN           NaN            NaN                NaN         NaN
# 1         NaN           NaN            NaN                NaN         NaN
# 2     Plastic         Glass  Ferrous Metal  Non-Ferrous Metal       Paper
# 3    5774 Kwh        42 Kwh        642 Kwh          14000 Kwh    4100 kWh
# 4  16 barrels  0.12 barrels    1.8 barrels         40 barrels  11 barrels

# %%
df2.dtypes
# Out:
# The table gives the amount of energy saved in kilowatt hour (kWh) and the amount of crude oil (barrels) by recycling 1 metric tonne (1000 kilogram)  per waste type    object
# Unnamed: 1                                                                                                                                                             object
# Unnamed: 2                                                                                                                                                             object
# Unnamed: 3                                                                                                                                                             object
# Unnamed: 4                                                                                                                                                             object
# Unnamed: 5                                                                                                                                                             object
# dtype: object

# %% [markdown]
# ##DATA ANALYSIS AND VISUALIZATION
#
# ---

# %%
df3 = pd.concat([df,df1])
df3.head()
#creating concat table
# Out:
#             waste_type  waste_disposed  waste_recycled  waste_generated  \
# 0                 Food          679900          111100           791000
# 1      Paper/Cardboard          576000          607100          1183100
# 2             Plastics          762700           59500           822200
# 3                  C&D            9700         1585700          1595400
# 4  Horticultural waste          111500          209000           320500
#
#    recycling_rate  year
# 0            0.14  2016
# 1            0.51  2016
# 2            0.07  2016
# 3            0.99  2016
# 4            0.65  2016

# %%
largest_waste1 = df3.groupby (['year'])['waste_generated'].sum()
waste= largest_waste1.sort_values(ascending=False).head(20).reset_index()      
waste
#total waste generated from 2003 to 2019 per year
# Out:
#     year  waste_generated
# 0   2019         29658000
# 1   2018         23707000
# 2   2020         17840000
# 3   2013         15703000
# 4   2016         15628400
# 5   2017         15408600
# 6   2015         15347000
# 7   2014         15028900
# 8   2012         14539000
# 9   2011         13796600
# 10  2010         13034000
# 11  2009         12228200
# 12  2008         11940400
# 13  2007         11201600
# 14  2006         10441000
# 15  2005         10036400
# 16  2004          9579400
# 17  2003          9456400

# %%
fig, axes = plt.subplots(figsize = (15,8))
fig.suptitle('total amount of waste in Singapore')
sns.barplot(data=waste, x=waste['year'], y=waste['waste_generated'])
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# In the year of 2018 and 2019 have a largest waste prouction. As per graph, 2020 looks less waste.

# %%
from matplotlib.ticker import MaxNLocator
ax = plt.figure(figsize=(10,8)).gca()
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.plot('year', 'waste_generated', data=waste, color='green')
plt.title("Top industries constanty contributed to the vast waste")
plt.xlabel("Year")
plt.ylabel("Tons")
plt.legend()
plt.show()

# %%
top_waste = df.groupby(['waste_type'])[['waste_generated','waste_recycled']].sum().sort_values(by='waste_generated',ascending=False).reset_index()
top_waste=top_waste[top_waste['waste_type'] != "Total"].iloc[:10]
top_waste
#waste types from the data 1 from 2003 to 2017 and the large contributer for waste in top 15.
# Out:
#                                 waste_type  waste_generated  waste_recycled
# 1                          Paper/Cardboard         18120800         9205200
# 2                                 Plastics         10252500          999100
# 3                      Construction Debris         10032100         9817800
# 4                            Ferrous Metal          7629100         7208700
# 5                               Food waste          6701500          698300
# 6                            Ferrous metal          5530700         5444700
# 7                                Used Slag          4342100         4130700
# 8                                      C&D          4276900         4248600
# 9   Others (stones, ceramics & rubber etc)          3433200           76100
# 10                                    Food          3174900          449600

# %%
top_waste_2= df1.groupby(['waste_type'])[['waste_generated','waste_recycled']].sum().sort_values(by='waste_generated',ascending=False).reset_index()
top_waste_2=top_waste_2[top_waste_2['waste_type'] != "Overall"]
top_waste_2.iloc[:10]
#waste types from the data 2 from 2018 to 2020 and the large contributer for waste in top 15.
# Out:
#                    waste_type  waste_generated  waste_recycled
# 1                        Food          9256000          388000
# 2    Construction& Demolition          6116000         3052000
# 3             Paper/Cardboard          4676000         1467000
# 4               Ferrous Metal          3943000         1396000
# 5                    Plastics          2861000          114000
# 6                        Wood          2175000          912000
# 7               Ferrous metal          1864000          930000
# 8               Horticultural          1802000          769000
# 9   Construction & Demolition          1647000          822000
# 10                  Used Slag           616000          306000

# %%
fig, axes = plt.subplots(nrows=4, ncols=4)
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

# %%
index = np.arange(10)
bar_width = 0.35
fig, ax = plt.subplots(2,figsize = (20,20))
summer = ax[0].bar(index, top_waste['waste_generated'], bar_width,
                label="waste_generated")

winter = ax[0].bar(index+bar_width, top_waste['waste_recycled'],
                 bar_width, label="waste_recycled")

ax[0].set_xlabel('')
ax[0].set_ylabel('Tons')
ax[0].set_title('Top waste in Singapore from 2003-2017')
ax[0].set_xticks(index + bar_width / 2)
ax[0].set_xticklabels(["Paper/Cardborad","Construction Debris", "Plastics", "Food", "Ferrous Metal", "Ferrous metal","Used Slag", "C&D","Others (stones, ceramics & rubber etc)","Food"],rotation = 90)
ax[0].legend()
summ = ax[1].bar(index, top_waste['waste_generated'], bar_width, label="waste_generated")

win = ax[1].bar(index+bar_width, top_waste['waste_recycled'], bar_width, label="waste_recycled")

ax[1].set_xlabel('Category')
ax[1].set_ylabel('Tons')
ax[1].set_title('Top waste in Singapore from 20018-2020')
ax[1].set_xticks(index + bar_width / 2)
ax[1].set_xticklabels([ "Food", "Construction/Demo","Paper/Cardborad","Ferrous Metal", "Plastics", "Wood", "Ferrous Metal", "Horticultural","Construction & Demolition","Used Slag"], rotation = 90)
ax[1].legend()

plt.show()

# %% [markdown]
# In current years, waste is changing from cardboards/papers towards foods.
#
# ---

# %%
data['waste'] = data['waste_type'].apply(lambda x: str(x).replace("Ferrous Metals", "Ferrous Metal" ))
data['waste_type'] = [i.replace("Ferrous metal", "Ferrous Metal") for i in data['waste']]
print(data['waste_type'].unique())
# Out:
# ['Food' 'Paper/Cardboard' 'Plastics' 'C&D' 'Horticultural waste' 'Wood'
#  'Ferrous Metal' 'Non-ferrous metal' 'Used slag' 'Ash & Sludge' 'Glass'
#  'Textile/Leather' 'Scrap tyres' 'Others (stones, ceramics & rubber etc.)'
#  'Total' 'Others (stones, ceramics & rubber etc)' 'Food waste'
#  'Construction Debris' 'Wood/Timber' 'Horticultural Waste'
#  'Non-ferrous Metals' 'Used Slag' 'Sludge' 'Scrap Tyres' 'Others'
#  'Construction debris' 'Non-ferrous metals' 'Ash and sludge' 'Plastic'
#  'Others (stones, ceramic, rubber, etc.)']

# %%
#  Check contribution of the Paper/Cardboard content
year= []
paper_waste= []
for row in data[data['waste_type'] =="Paper/Cardboard"].itertuples():
    year.append(getattr(row, 'year'))
    paper_waste.append(getattr(row,"waste_generated"))
paper_waste = pd.DataFrame({'year':year, 'paper_waste':paper_waste})
# paper_card = pd.pivot_table(data=papercard,index ="paper_waste" )
# print(paper_card)

#Check contribution of the Plastic content
year1= []
plastic_waste= []
for row in data[data['waste_type'] == "Plastics"].itertuples():
    year1.append(getattr(row, 'year'))
    plastic_waste.append(getattr(row, 'waste_generated'))
plastic_waste = pd.DataFrame({'year':year1, 'plastic_waste':plastic_waste})


#Check contribution of the Plastic content
year2= []
metal_waste= []
#  Check contribution of the Paper/Cardboard content
for row in data[data['waste_type'] == "Ferrous Metal"].itertuples():
    year2.append(getattr(row, 'year'))
    metal_waste.append(getattr(row, 'waste_generated'))
metal_waste = pd.DataFrame({'year':year2, 'metal_waste':metal_waste})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-154-78fadf1d3971> in <module>()
#       3 paper_waste= []
#       4 for row in data[data['waste_type'] =="Paper/Cardboard"].itertuples():
# ----> 5     year.append(getattr(row, 'year'))
#       6     paper_waste.append(getattr(row,"waste_generated"))
#       7 paper_waste = pd.DataFrame({'year':year, 'paper_waste':paper_waste})
#
# AttributeError: 'Pandas' object has no attribute 'year'

# %%
# create the daframe for the newly data
df0 = paper_waste.merge(plastic_waste, how='inner', on='year')
df1 =df0.merge(metal_waste, how='inner', on='year')
df1=df1.sort_values(by='year', ascending=True)
df1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-150-8a1950a82fac> in <module>()
#       1 # create the daframe for the newly data
# ----> 2 df0 = paper_waste.merge(plastic_waste, how='inner', on='year')
#       3 df1 =df0.merge(metal_waste, how='inner', on='year')
#       4 df1=df1.sort_values(by='year', ascending=True)
#       5 df1
#
# AttributeError: 'list' object has no attribute 'merge'
