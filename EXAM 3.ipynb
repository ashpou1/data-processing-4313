# %% [markdown]
# <a href="https://colab.research.google.com/github/ashpou1/data-processing-4313/blob/main/EXAM%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ASHOK SHARMA POUDEL
# #218380
# #DATA PROCESSING VISUALIZATION  4313
# #DR. NICHOLAS JACOB

# %% [markdown]
# ##EXAM 3
# "I attest that the resources above were the only ones utilized in completing the exam and the work included is my own and no one else from the course."

# %% [markdown]
# lets load all libraries
#
# ---

# %%
import pandas as pa
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading my world cup player data set in panda data frame
#
# ---

# %%
df = pa.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Viz/main/worldCupPlayer.csv')
df.head()
# Out:
#    Unnamed: 0  Rank               player           club  age   Apps  Mins  \
# 0           0     1         Hakim Ziyech           Ajax   25     34  3043
# 1           2     2  Alireza Jahanbakhsh     AZ Alkmaar   24     33  2840
# 2           4     3       Hirving Lozano  PSV Eindhoven   22     29  2350
# 3           6    11         Lasse Schone           Ajax   32  27(3)  2350
# 4          10    25       Santiago Arias  PSV Eindhoven   26     30  2664
#
#    Goals  Assists  Yel  Red  SpG    PS AerialsWon  MotM  Rating nationality
# 0      9       15    4    0  4.9  75.4        0.2     9    8.21     Morocco
# 1     21       12    3    0  4.3  73.4        0.7    14    8.20        Iran
# 2     17        8    4    2  3.4  75.3        0.6     8    7.90      Mexico
# 3     10        3    6    0  1.9  87.0        1.9     2    7.45     Denmark
# 4      3        6    5    0  1.5  82.3          1     2    7.25    Colombia

# %% [markdown]
# From whole data i will select my club Barcelona and i will compare Lionel Messi with Luies Suarez in the contest highest goals, assists and lowest yellow card.
#
# ---

# %%
df1 = df[df["club"] == 'Barcelona' ]
df1
#https://pandas.pydata.org/docs/getting_started/intro_tutorials/03_subset_data.html
# Out:
#      Unnamed: 0  Rank                 player       club  age    Apps  Mins  \
# 169         331    99               Paulinho  Barcelona   29  21(13)  1941
# 173         339   332               Paulinho  Barcelona   29    4(5)   402
# 194         381     1           Lionel Messi  Barcelona   30   32(4)  2997
# 195         382     6           Lionel Messi  Barcelona   30    8(2)   783
# 198         385     3            Luis Suarez  Barcelona   31   32(1)  2902
# 199         386   203            Luis Suarez  Barcelona   31      10   884
# 209         402    16        Sergio Busquets  Barcelona   29   30(1)  2600
# 210         404   122        Sergio Busquets  Barcelona   29    9(1)   768
# 211         406    18             Jordi Alba  Barcelona   29   30(3)  2745
# 212         408   217             Jordi Alba  Barcelona   29    7(1)   638
# 213         410    25           Gerard Pique  Barcelona   31   29(1)  2633
# ...

# %% [markdown]
# lets see the data:
#
# lionel Messi has the highest goal of 34 compare to 25 and same assists as Luis Suarez of 12 but he have only 3 yellow cards compared 9 yellow cards.

# %% [markdown]
# ##) (10 points) Create a histogram of the ‘Goals’.
#
# ---

# %%
df.Goals.plot.hist(title = 'Histogram of Goals',ylim=[0,450]).set_xlabel("Goals")
# Out:
# Text(0.5, 0, 'Goals')

# %% [markdown]
# ##(d) (10 points) Create a histogram of the ‘Goals’ and ‘Assists’ on the same axis.
#
# ---

# %%
df[["Goals", "Assists"]].plot.hist()

# %% [markdown]
# ##(e) (10 points) Create a barchart for most goals scored by nationality.
#
# ---

# %%
ax = df2.groupby(['neighbourhood_group','room_type']).price.agg('mean').plot(kind = 'barh',
                                                                       title = 'Average price in each neighbourhood group',)
for container in ax.containers:
    ax.bar_label(container)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-c1f0f27dac20> in <module>()
# ----> 1 ax = df2.groupby(['neighbourhood_group','room_type']).price.agg('mean').plot(kind = 'barh',
#       2                                                                        title = 'Average price in each neighbourhood group',)
#       3 for container in ax.containers:
#       4     ax.bar_label(container)
#
# NameError: name 'df2' is not defined

# %% [markdown]
# ##(f) (10 points) Create a boxplot of ‘Yel’ (yellow cards) by nationality.
#
# ---

# %% [markdown]
# ##(g) (10 points) Create ‘Goals’ and ‘Assists’ as scatter. Signify your favorite club or nationality in some way on the scatterplot. You may need to add a new column to the dataset to do so.
#
# ---

# %% [markdown]
# ##(h) (10 points) Create stacked barplot of goals and assists of French National Team. (they won this tourney!) Be sure to comment on why it is appropriate to stack goals and assists.
#
# ---

# %% [markdown]
# ##(i) (10 points) Create a correlation heatmap of the entire dataset.
#
# ---

# %% [markdown]
# ##ABOUT EXAM
#
# ---

# %% [markdown]
# ---
# (a) Approximately how long did you work on this exam?
#
#
# (b) Which was the hardest and easiest topic from this section?
#
#
# (c) Which method of visualization are you still unclear what it might show?
